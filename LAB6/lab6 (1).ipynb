# %%
import pandas as pd
data = pd.read_csv('salary.csv')
print(data.head())
# Out:
#    exp(in months)  salary(in thousands)
# 0       18.290293             16.521825
# 1       17.023407             11.666234
# 2       26.343613             23.167255
# 3       19.105834             20.877145
# 4       27.742516             23.166236

# %%
x = data['exp(in months)'].values.reshape(-1,1)
y = data['salary(in thousands)'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R-squared (R2) Score:", mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error (MAE): 4.1621356133144705
# Mean Squared Error (MSE): 27.650268732842278
# R-squared (R2) Score: 27.650268732842278

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test, y_test, color='green')
plt.plot(x_test, y_pred, color='red', linewidth=3)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.show()
